# %%
pip install torch torchvision matplotlib
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)

# %%
import torch
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)

batch_size = 128
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)

print(f"Number of training samples: {len(train_dataset)}")
print(f"Number of batches in training loader: {len(train_loader)}")
# Out:
# Number of training samples: 60000
# Number of batches in training loader: 469

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim, img_shape):
        super().__init__()
        self.img_shape = img_shape

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(128, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, int(torch.prod(torch.tensor(img_shape)))),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        img = img.view(img.size(0), *self.img_shape)
        return img

# testing
latent_dim = 100
img_shape = (1, 28, 28)
generator = Generator(latent_dim, img_shape)
print(generator)
# Out:
# Generator(
#   (model): Sequential(
#     (0): Linear(in_features=100, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.2, inplace=True)
#     (4): Linear(in_features=256, out_features=512, bias=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#     (6): Linear(in_features=512, out_features=784, bias=True)
#     (7): Tanh()
#   )
# )

# %%
class Discriminator(nn.Module):
    def __init__(self, img_shape):
        super().__init__()
        self.img_shape = img_shape

        self.model = nn.Sequential(
            nn.Linear(int(torch.prod(torch.tensor(img_shape))), 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid() # using Sigmoid for binary classification output
        )

    def forward(self, img):
        img_flat = img.view(img.size(0), -1)
        validity = self.model(img_flat)
        return validity

# testing
img_shape = (1, 28, 28)
discriminator = Discriminator(img_shape)
print(discriminator)
# Out:
# Discriminator(
#   (model): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.2, inplace=True)
#     (4): Linear(in_features=256, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )

# %%
import torch.optim as optim
adversarial_loss = nn.BCELoss()

learning_rate = 0.0002
beta1 = 0.5
beta2 = 0.999
optimizer_g = optim.Adam(generator.parameters(), lr=learning_rate, betas=(beta1, beta2))

optimizer_d = optim.Adam(discriminator.parameters(), lr=learning_rate, betas=(beta1, beta2))

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

generator.to(device)
discriminator.to(device)

num_epochs = 50

# training loop
print("Starting training loop...")
for epoch in range(num_epochs):
    for i, (imgs, _) in enumerate(train_loader):

        real_imgs = imgs.to(device)
        real_labels = torch.ones(imgs.size(0), 1).to(device)
        fake_labels = torch.zeros(imgs.size(0), 1).to(device)

        optimizer_d.zero_grad()

        real_output = discriminator(real_imgs)
        d_loss_real = adversarial_loss(real_output, real_labels)

        z = torch.randn(imgs.size(0), latent_dim).to(device)
        fake_imgs = generator(z).detach()

        fake_output = discriminator(fake_imgs)
        d_loss_fake = adversarial_loss(fake_output, fake_labels)

        d_loss = (d_loss_real + d_loss_fake) / 2

        d_loss.backward()
        optimizer_d.step()

        optimizer_g.zero_grad()

        z = torch.randn(imgs.size(0), latent_dim).to(device)
        fake_imgs = generator(z)

        g_loss = adversarial_loss(discriminator(fake_imgs), real_labels)

        g_loss.backward()
        optimizer_g.step()

        if (i + 1) % 100 == 0:
            print(
                f"[Epoch {epoch}/{num_epochs}] [Batch {i+1}/{len(train_loader)}] "
                f"[D loss: {d_loss.item():.4f}] [G loss: {g_loss.item():.4f}]"
            )

    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(25, latent_dim).to(device)
            generated_images = generator(z).cpu()
            print(f"Epoch {epoch+1}: Generated sample images.")

print("Training finished.")
# Out:
# Using device: cpu
# Starting training loop...
# [Epoch 0/50] [Batch 100/469] [D loss: 0.3778] [G loss: 1.0209]
# [Epoch 0/50] [Batch 200/469] [D loss: 0.4805] [G loss: 1.1792]
# [Epoch 0/50] [Batch 300/469] [D loss: 0.7308] [G loss: 1.7267]
# [Epoch 0/50] [Batch 400/469] [D loss: 0.2855] [G loss: 2.6372]
# [Epoch 1/50] [Batch 100/469] [D loss: 0.3068] [G loss: 1.0885]
# [Epoch 1/50] [Batch 200/469] [D loss: 0.1738] [G loss: 2.6256]
# [Epoch 1/50] [Batch 300/469] [D loss: 0.1995] [G loss: 2.6953]
# [Epoch 1/50] [Batch 400/469] [D loss: 0.1971] [G loss: 3.3153]
# [Epoch 2/50] [Batch 100/469] [D loss: 0.2871] [G loss: 1.8313]
# [Epoch 2/50] [Batch 200/469] [D loss: 0.3434] [G loss: 1.2846]
# [Epoch 2/50] [Batch 300/469] [D loss: 0.2732] [G loss: 2.0461]
# [Epoch 2/50] [Batch 400/469] [D loss: 0.3809] [G loss: 3.3787]
# [Epoch 3/50] [Batch 100/469] [D loss: 0.2486] [G loss: 4.3961]
# [Epoch 3/50] [Batch 200/469] [D loss: 0.1927] [G loss: 3.3986]
# [Epoch 3/50] [Batch 300/469] [D loss: 0.1879] [G loss: 2.7285]
# [Epoch 3/50] [Batch 400/469] [D loss: 0.1568] [G loss: 3.4188]
# [Epoch 4/50] [Batch 100/469] [D loss: 0.1458] [G loss: 3.5238]
# [Epoch 4/50] [Batch 200/469] [D loss: 0.2627] [G loss: 2.0179]
# [Epoch 4/50] [Batch 300/469] [D loss: 0.4903] [G loss: 3.7088]
# [Epoch 4/50] [Batch 400/469] [D loss: 0.1665] [G loss: 2.3864]
# [Epoch 5/50] [Batch 100/469] [D loss: 0.1647] [G loss: 3.4363]
# [Epoch 5/50] [Batch 200/469] [D loss: 0.2100] [G loss: 3.2922]
# [Epoch 5/50] [Batch 300/469] [D loss: 0.4192] [G loss: 2.2056]
# [Epoch 5/50] [Batch 400/469] [D loss: 0.4349] [G loss: 1.1700]
# [Epoch 6/50] [Batch 100/469] [D loss: 0.2039] [G loss: 2.3898]
# [Epoch 6/50] [Batch 200/469] [D loss: 0.1788] [G loss: 2.0349]
# [Epoch 6/50] [Batch 300/469] [D loss: 0.4634] [G loss: 5.3552]
# [Epoch 6/50] [Batch 400/469] [D loss: 0.1681] [G loss: 2.2681]
# [Epoch 7/50] [Batch 100/469] [D loss: 0.2002] [G loss: 2.2996]
# [Epoch 7/50] [Batch 200/469] [D loss: 0.3396] [G loss: 2.2173]
# [Epoch 7/50] [Batch 300/469] [D loss: 0.2119] [G loss: 3.3361]
# [Epoch 7/50] [Batch 400/469] [D loss: 0.3240] [G loss: 2.9250]
# [Epoch 8/50] [Batch 100/469] [D loss: 0.1866] [G loss: 2.6826]
# [Epoch 8/50] [Batch 200/469] [D loss: 0.1453] [G loss: 3.7541]
# [Epoch 8/50] [Batch 300/469] [D loss: 0.2883] [G loss: 1.9683]
# [Epoch 8/50] [Batch 400/469] [D loss: 0.3088] [G loss: 3.3314]
# [Epoch 9/50] [Batch 100/469] [D loss: 0.2239] [G loss: 2.2567]
# [Epoch 9/50] [Batch 200/469] [D loss: 0.2860] [G loss: 3.9181]
# [Epoch 9/50] [Batch 300/469] [D loss: 0.2005] [G loss: 2.0168]
# [Epoch 9/50] [Batch 400/469] [D loss: 0.2885] [G loss: 1.7645]
# Epoch 10: Generated sample images.
# [Epoch 10/50] [Batch 100/469] [D loss: 0.2386] [G loss: 2.9056]
# [Epoch 10/50] [Batch 200/469] [D loss: 0.2469] [G loss: 3.0585]
# [Epoch 10/50] [Batch 300/469] [D loss: 0.2049] [G loss: 2.8583]
# [Epoch 10/50] [Batch 400/469] [D loss: 0.3096] [G loss: 2.1870]
# [Epoch 11/50] [Batch 100/469] [D loss: 0.3582] [G loss: 1.7342]
# [Epoch 11/50] [Batch 200/469] [D loss: 0.3244] [G loss: 4.6700]
# [Epoch 11/50] [Batch 300/469] [D loss: 0.2892] [G loss: 2.2884]
# [Epoch 11/50] [Batch 400/469] [D loss: 0.5374] [G loss: 5.6696]
# [Epoch 12/50] [Batch 100/469] [D loss: 0.2364] [G loss: 2.5126]
# [Epoch 12/50] [Batch 200/469] [D loss: 0.4296] [G loss: 4.6334]
# [Epoch 12/50] [Batch 300/469] [D loss: 0.3247] [G loss: 2.9320]
# [Epoch 12/50] [Batch 400/469] [D loss: 0.3337] [G loss: 2.7282]
# [Epoch 13/50] [Batch 100/469] [D loss: 0.2369] [G loss: 1.7745]
# [Epoch 13/50] [Batch 200/469] [D loss: 0.3848] [G loss: 1.6120]
# [Epoch 13/50] [Batch 300/469] [D loss: 0.2700] [G loss: 1.6015]
# [Epoch 13/50] [Batch 400/469] [D loss: 0.3366] [G loss: 1.1178]
# [Epoch 14/50] [Batch 100/469] [D loss: 0.3634] [G loss: 2.7102]
# [Epoch 14/50] [Batch 200/469] [D loss: 0.2989] [G loss: 1.6991]
# [Epoch 14/50] [Batch 300/469] [D loss: 0.2503] [G loss: 2.0218]
# [Epoch 14/50] [Batch 400/469] [D loss: 0.3153] [G loss: 2.2471]
# [Epoch 15/50] [Batch 100/469] [D loss: 0.2945] [G loss: 1.9583]
# [Epoch 15/50] [Batch 200/469] [D loss: 0.4128] [G loss: 3.5633]
# [Epoch 15/50] [Batch 300/469] [D loss: 0.4210] [G loss: 1.0864]
# [Epoch 15/50] [Batch 400/469] [D loss: 0.3004] [G loss: 1.8457]
# [Epoch 16/50] [Batch 100/469] [D loss: 0.3168] [G loss: 2.1353]
# [Epoch 16/50] [Batch 200/469] [D loss: 0.3355] [G loss: 1.6493]
# [Epoch 16/50] [Batch 300/469] [D loss: 0.4364] [G loss: 2.2216]
# [Epoch 16/50] [Batch 400/469] [D loss: 0.3409] [G loss: 1.7322]
# [Epoch 17/50] [Batch 100/469] [D loss: 0.3736] [G loss: 1.5588]
# [Epoch 17/50] [Batch 200/469] [D loss: 0.5375] [G loss: 0.4950]
# [Epoch 17/50] [Batch 300/469] [D loss: 0.4356] [G loss: 2.3874]
# [Epoch 17/50] [Batch 400/469] [D loss: 0.5492] [G loss: 0.9163]
# [Epoch 18/50] [Batch 100/469] [D loss: 0.7294] [G loss: 0.7101]
# [Epoch 18/50] [Batch 200/469] [D loss: 0.4086] [G loss: 0.9645]
# [Epoch 18/50] [Batch 300/469] [D loss: 0.5134] [G loss: 0.9353]
# [Epoch 18/50] [Batch 400/469] [D loss: 0.5185] [G loss: 0.8354]
# [Epoch 19/50] [Batch 100/469] [D loss: 0.3360] [G loss: 1.2799]
# [Epoch 19/50] [Batch 200/469] [D loss: 0.4508] [G loss: 2.4503]
# [Epoch 19/50] [Batch 300/469] [D loss: 0.4853] [G loss: 1.1351]
# [Epoch 19/50] [Batch 400/469] [D loss: 0.4305] [G loss: 1.0771]
# Epoch 20: Generated sample images.
# [Epoch 20/50] [Batch 100/469] [D loss: 0.4984] [G loss: 2.0107]
# [Epoch 20/50] [Batch 200/469] [D loss: 0.5963] [G loss: 0.7755]
# [Epoch 20/50] [Batch 300/469] [D loss: 0.3935] [G loss: 1.5153]
# [Epoch 20/50] [Batch 400/469] [D loss: 0.4776] [G loss: 1.6072]
# [Epoch 21/50] [Batch 100/469] [D loss: 0.4865] [G loss: 1.0505]
# [Epoch 21/50] [Batch 200/469] [D loss: 0.4851] [G loss: 1.2258]
# [Epoch 21/50] [Batch 300/469] [D loss: 0.4498] [G loss: 1.0930]
# [Epoch 21/50] [Batch 400/469] [D loss: 0.5029] [G loss: 0.9209]
# [Epoch 22/50] [Batch 100/469] [D loss: 0.6809] [G loss: 2.7713]
# [Epoch 22/50] [Batch 200/469] [D loss: 0.4610] [G loss: 1.5060]
# [Epoch 22/50] [Batch 300/469] [D loss: 0.4486] [G loss: 0.9965]
# [Epoch 22/50] [Batch 400/469] [D loss: 0.4694] [G loss: 1.8878]
# [Epoch 23/50] [Batch 100/469] [D loss: 0.4496] [G loss: 1.3752]
# [Epoch 23/50] [Batch 200/469] [D loss: 0.4949] [G loss: 1.1280]
# [Epoch 23/50] [Batch 300/469] [D loss: 0.4454] [G loss: 1.8081]
# [Epoch 23/50] [Batch 400/469] [D loss: 0.5166] [G loss: 2.2649]
# [Epoch 24/50] [Batch 100/469] [D loss: 0.4989] [G loss: 1.0376]
# [Epoch 24/50] [Batch 200/469] [D loss: 0.6264] [G loss: 0.6295]
# [Epoch 24/50] [Batch 300/469] [D loss: 0.4645] [G loss: 1.8280]
# [Epoch 24/50] [Batch 400/469] [D loss: 0.4463] [G loss: 1.2183]
# [Epoch 25/50] [Batch 100/469] [D loss: 0.5293] [G loss: 0.8488]
# [Epoch 25/50] [Batch 200/469] [D loss: 0.4679] [G loss: 1.6463]
# [Epoch 25/50] [Batch 300/469] [D loss: 0.5047] [G loss: 0.8696]
# [Epoch 25/50] [Batch 400/469] [D loss: 0.4977] [G loss: 1.2976]
# [Epoch 26/50] [Batch 100/469] [D loss: 0.4230] [G loss: 1.0967]
# [Epoch 26/50] [Batch 200/469] [D loss: 0.4646] [G loss: 1.2396]
# [Epoch 26/50] [Batch 300/469] [D loss: 0.4239] [G loss: 1.4586]
# [Epoch 26/50] [Batch 400/469] [D loss: 0.4457] [G loss: 1.0223]
# [Epoch 27/50] [Batch 100/469] [D loss: 0.4569] [G loss: 0.8158]
# [Epoch 27/50] [Batch 200/469] [D loss: 0.5280] [G loss: 0.7397]
# [Epoch 27/50] [Batch 300/469] [D loss: 0.5417] [G loss: 0.9113]
# [Epoch 27/50] [Batch 400/469] [D loss: 0.4671] [G loss: 1.8148]
# [Epoch 28/50] [Batch 100/469] [D loss: 0.5466] [G loss: 2.1094]
# [Epoch 28/50] [Batch 200/469] [D loss: 0.6197] [G loss: 2.0029]
# [Epoch 28/50] [Batch 300/469] [D loss: 0.5275] [G loss: 1.8353]
# [Epoch 28/50] [Batch 400/469] [D loss: 0.4866] [G loss: 2.0072]
# [Epoch 29/50] [Batch 100/469] [D loss: 0.4706] [G loss: 1.3985]
# [Epoch 29/50] [Batch 200/469] [D loss: 0.4984] [G loss: 1.8753]
# [Epoch 29/50] [Batch 300/469] [D loss: 0.5117] [G loss: 1.8340]
# [Epoch 29/50] [Batch 400/469] [D loss: 0.4390] [G loss: 1.2235]
# Epoch 30: Generated sample images.
# [Epoch 30/50] [Batch 100/469] [D loss: 0.6320] [G loss: 2.0278]
# [Epoch 30/50] [Batch 200/469] [D loss: 0.4478] [G loss: 1.0262]
# [Epoch 30/50] [Batch 300/469] [D loss: 0.4614] [G loss: 1.5817]
# [Epoch 30/50] [Batch 400/469] [D loss: 0.5188] [G loss: 1.5902]
# [Epoch 31/50] [Batch 100/469] [D loss: 0.4513] [G loss: 1.4179]
# [Epoch 31/50] [Batch 200/469] [D loss: 0.4810] [G loss: 1.6581]
# [Epoch 31/50] [Batch 300/469] [D loss: 0.4899] [G loss: 1.0288]
# [Epoch 31/50] [Batch 400/469] [D loss: 0.4827] [G loss: 1.9298]
# [Epoch 32/50] [Batch 100/469] [D loss: 0.5873] [G loss: 0.5223]
# [Epoch 32/50] [Batch 200/469] [D loss: 0.4918] [G loss: 1.1320]
# [Epoch 32/50] [Batch 300/469] [D loss: 0.4613] [G loss: 1.5091]
# [Epoch 32/50] [Batch 400/469] [D loss: 0.4753] [G loss: 0.9649]
# [Epoch 33/50] [Batch 100/469] [D loss: 0.5268] [G loss: 0.8326]
# [Epoch 33/50] [Batch 200/469] [D loss: 0.5292] [G loss: 0.9858]
# [Epoch 33/50] [Batch 300/469] [D loss: 0.5308] [G loss: 2.0529]
# [Epoch 33/50] [Batch 400/469] [D loss: 0.5013] [G loss: 1.2671]
# [Epoch 34/50] [Batch 100/469] [D loss: 0.5470] [G loss: 0.6318]
# [Epoch 34/50] [Batch 200/469] [D loss: 0.5057] [G loss: 0.9948]
# [Epoch 34/50] [Batch 300/469] [D loss: 0.4362] [G loss: 1.1616]
# [Epoch 34/50] [Batch 400/469] [D loss: 0.4409] [G loss: 1.4272]
# [Epoch 35/50] [Batch 100/469] [D loss: 0.4972] [G loss: 1.4353]
# [Epoch 35/50] [Batch 200/469] [D loss: 0.5272] [G loss: 0.9710]
# [Epoch 35/50] [Batch 300/469] [D loss: 0.4948] [G loss: 0.9071]
# [Epoch 35/50] [Batch 400/469] [D loss: 0.4739] [G loss: 1.7091]
# [Epoch 36/50] [Batch 100/469] [D loss: 0.4711] [G loss: 1.1875]
# [Epoch 36/50] [Batch 200/469] [D loss: 0.4581] [G loss: 1.4403]
# [Epoch 36/50] [Batch 300/469] [D loss: 0.6217] [G loss: 0.6370]
# [Epoch 36/50] [Batch 400/469] [D loss: 0.5040] [G loss: 0.9625]
# [Epoch 37/50] [Batch 100/469] [D loss: 0.4506] [G loss: 1.1252]
# [Epoch 37/50] [Batch 200/469] [D loss: 0.5132] [G loss: 1.6084]
# [Epoch 37/50] [Batch 300/469] [D loss: 0.4626] [G loss: 1.4975]
# [Epoch 37/50] [Batch 400/469] [D loss: 0.4730] [G loss: 1.1557]
# [Epoch 38/50] [Batch 100/469] [D loss: 0.5519] [G loss: 2.3861]
# [Epoch 38/50] [Batch 200/469] [D loss: 0.4878] [G loss: 1.7163]
# [Epoch 38/50] [Batch 300/469] [D loss: 0.6182] [G loss: 2.2053]
# [Epoch 38/50] [Batch 400/469] [D loss: 0.4898] [G loss: 1.1008]
# [Epoch 39/50] [Batch 100/469] [D loss: 0.4685] [G loss: 1.4091]
# [Epoch 39/50] [Batch 200/469] [D loss: 0.4911] [G loss: 1.0193]
# [Epoch 39/50] [Batch 300/469] [D loss: 0.6765] [G loss: 2.3631]
# [Epoch 39/50] [Batch 400/469] [D loss: 0.5030] [G loss: 1.5305]
# Epoch 40: Generated sample images.
# [Epoch 40/50] [Batch 100/469] [D loss: 0.4418] [G loss: 1.4575]
# [Epoch 40/50] [Batch 200/469] [D loss: 0.5263] [G loss: 1.7301]
# [Epoch 40/50] [Batch 300/469] [D loss: 0.6053] [G loss: 1.0527]
# [Epoch 40/50] [Batch 400/469] [D loss: 0.4648] [G loss: 1.5138]
# [Epoch 41/50] [Batch 100/469] [D loss: 0.4546] [G loss: 1.6898]
# [Epoch 41/50] [Batch 200/469] [D loss: 0.4742] [G loss: 1.5986]
# [Epoch 41/50] [Batch 300/469] [D loss: 0.5037] [G loss: 0.9826]
# [Epoch 41/50] [Batch 400/469] [D loss: 0.5972] [G loss: 0.7670]
# [Epoch 42/50] [Batch 100/469] [D loss: 0.4686] [G loss: 1.6316]
# [Epoch 42/50] [Batch 200/469] [D loss: 0.4558] [G loss: 1.4300]
# [Epoch 42/50] [Batch 300/469] [D loss: 0.5439] [G loss: 2.1653]
# [Epoch 42/50] [Batch 400/469] [D loss: 0.5998] [G loss: 2.4040]
# [Epoch 43/50] [Batch 100/469] [D loss: 0.4944] [G loss: 1.1663]
# [Epoch 43/50] [Batch 200/469] [D loss: 0.5387] [G loss: 0.9285]
# [Epoch 43/50] [Batch 300/469] [D loss: 0.4886] [G loss: 1.0441]
# [Epoch 43/50] [Batch 400/469] [D loss: 0.5741] [G loss: 1.6398]
# [Epoch 44/50] [Batch 100/469] [D loss: 0.5673] [G loss: 1.9921]
# [Epoch 44/50] [Batch 200/469] [D loss: 0.4820] [G loss: 1.9275]
# [Epoch 44/50] [Batch 300/469] [D loss: 0.4675] [G loss: 1.9800]
# [Epoch 44/50] [Batch 400/469] [D loss: 0.5141] [G loss: 2.0689]
# [Epoch 45/50] [Batch 100/469] [D loss: 0.7215] [G loss: 2.1684]
# [Epoch 45/50] [Batch 200/469] [D loss: 0.5528] [G loss: 0.5003]
# [Epoch 45/50] [Batch 300/469] [D loss: 0.5268] [G loss: 1.2569]
# [Epoch 45/50] [Batch 400/469] [D loss: 0.5023] [G loss: 1.2650]
# [Epoch 46/50] [Batch 100/469] [D loss: 0.4739] [G loss: 1.6164]
# [Epoch 46/50] [Batch 200/469] [D loss: 0.4261] [G loss: 1.5184]
# [Epoch 46/50] [Batch 300/469] [D loss: 0.4450] [G loss: 1.6247]
# [Epoch 46/50] [Batch 400/469] [D loss: 0.4467] [G loss: 1.3370]
# [Epoch 47/50] [Batch 100/469] [D loss: 0.5561] [G loss: 0.7431]
# [Epoch 47/50] [Batch 200/469] [D loss: 0.4515] [G loss: 1.4285]
# [Epoch 47/50] [Batch 300/469] [D loss: 0.5713] [G loss: 2.0300]
# [Epoch 47/50] [Batch 400/469] [D loss: 0.4448] [G loss: 1.2953]
# [Epoch 48/50] [Batch 100/469] [D loss: 0.4525] [G loss: 1.1230]
# [Epoch 48/50] [Batch 200/469] [D loss: 0.4931] [G loss: 0.9233]
# [Epoch 48/50] [Batch 300/469] [D loss: 0.5987] [G loss: 1.6704]
# [Epoch 48/50] [Batch 400/469] [D loss: 0.4714] [G loss: 1.2793]
# [Epoch 49/50] [Batch 100/469] [D loss: 0.5243] [G loss: 1.5761]
# [Epoch 49/50] [Batch 200/469] [D loss: 0.5137] [G loss: 1.6720]
# [Epoch 49/50] [Batch 300/469] [D loss: 0.5225] [G loss: 2.0097]
# [Epoch 49/50] [Batch 400/469] [D loss: 0.4415] [G loss: 1.5403]
# Epoch 50: Generated sample images.
# Training finished.

# %%
import matplotlib.pyplot as plt
import numpy as np

with torch.no_grad():
    z = torch.randn(25, latent_dim).to(device)
    generated_images = generator(z).cpu()

fig, axes = plt.subplots(5, 5, figsize=(8, 8))
for i, ax in enumerate(axes.flat):
    ax.imshow(np.squeeze(generated_images[i].permute(1, 2, 0).numpy()), cmap='gray')
    ax.axis('off')
plt.suptitle("Generated MNIST Digits")
plt.show()
